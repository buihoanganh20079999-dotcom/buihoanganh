# %%
num = int(input("Nhập một số nguyên: "))
print("Số đảo ngược là: ", str(num)[::-1])
# Out:
# Nhập một số nguyên: 567
# Số đảo ngược là:  765

# %%
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
a = a ^ b
b = a ^ b
a = a ^ b
print("Số a sau khi hoán đổi: ", a)
print("Số b sau khi hoán đổi: ", b)
# Out:
# Nhập số a: 5
# Nhập số b: 1
# Số a sau khi hoán đổi:  1
# Số b sau khi hoán đổi:  5

# %%
n = int(input("Nhập số nguyên n : "))
if n & (n-1) == 0:
    print(n, "là lũy thừa của 2")
else:
    print(n, "không phải lũy thừa của 2")
# Out:
# Nhập số nguyên n : 5
# 5 không phải lũy thừa của 2

# %%
a, b = map(int, input("Nhập 2 số a và b: ").split())
c = a / b
if round(c) > c:
    print("Thương làm tròn xuống của a chia b là: ", round(c) - 1)
else:
    print("Thương làm tròn xuống của a chia b là: ", round(c))
# Out:
# Nhập 2 số a và b: 53 46
# Thương làm tròn xuống của a chia b là:  1

# %%
a, b = map(int, input("Nhập 2 số a và b: ").split())
c = a / b
if round(c) > c:
    print("Thương làm tròn lên của a chia b là: ", round(c))
else:
    print("Thương làm tròn lên của a chia b là: ", round(c)+1)
# Out:
# Nhập 2 số a và b: 53 46
# Thương làm tròn lên của a chia b là:  2

# %%
n = int(input("Nhập số nguyên n: "))
if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Nhập số nguyên n: 5
# Odd

# %%
a, b = map(int, input("Nhập 2 số a và b: ").split())
if a * b > 0 and a + b < 0:
    print("Yes ")
else:
    print("No")
# Out:
# Nhập 2 số a và b: 5 7
# No

# %%
a = input("Nhập chuỗi a: ")
b = input("Nhập chuỗi b: ")
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# Nhập chuỗi a: abcd
# Nhập chuỗi b: efg
# True

# %%
a, b, c = map(int, input("Nhập độ dài 3 cạnh tam giác a, b, c: ").split())
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")
# Out:
# Nhập độ dài 3 cạnh tam giác a, b, c: 3 4 5
# Yes

# %%
a, b, c, d = map(int, input("Nhập 4 số a, b, c, d: ").split())
list = [a, b, c, d]
print("Số lớn nhất trong 4 số là: ", max(list))
# Out:
# Nhập 4 số a, b, c, d: 4 6 1 8
# Số lớn nhất trong 4 số là:  8

# %%
a, b, c = map(int, input("Nhập độ dài 3 cạnh tam giác a, b, c: ").split())
if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Tam giác đều")
    elif a == b or b == c or a == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")
# Out:
# Nhập độ dài 3 cạnh tam giác a, b, c: 4 9 12
# Tam giác thường

# %%
year = int(input("Nhập năm: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    pri2025nt("Yes")
else:
    print("No")
# Out:
# Nhập năm: 2025
# No

# %%
e = int(input("Nhập số kWh: "))
for i in range(1, e+1):
    if i <= 50:
        money = i * 1500
    elif i <= 100:
        money = 50 * 1500 + (i - 50) * 2000
    else:
        money = 50 * 1500 + 50 * 2000 + (i - 100) * 3000
print(money)
# Out:
# Nhập số kWh: 60
# 95000

# %%
a = float(input("Nhập hệ số a: "))
b = float(input("Nhập hệ số b: "))
if a == 0 and b == 0:
    print("Vô số nghiệm")
elif a == 0 and b != 0:
    print("Vô nghiệm")
else:
    print("Phương trình có nghiệm x =", round(-b / a, 2))
# Out:
# Nhập hệ số a: 3
# Nhập hệ số b: 2
# Phương trình có nghiệm x = -0.67

# %%
diem = float(input("Nhập điểm trung bình: "))
if diem >= 8.0:
    print("Giỏi")
elif diem >= 6.5:
    print("Khá")
elif diem >= 5.0:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Nhập điểm trung bình: 7.89
# Khá

# %%
def round_up(x):
    if round(x) > x:
        return round(x)
    else:
        return round(x) + 1

def round_down(x):
    if round(x) > x:
        return round(x) - 1
    else:
        return round(x)

n = float(input("Nhập số thực: "))
print(round_up(n), round_down(n), round(n))
# Out:
# Nhập số thực: 2.468
# 3 2 2
